# %%
import requests
import pandas as pd
import os
from datetime import datetime
from dotenv import load_dotenv
import logging
from pytz import timezone
import numpy as np

load_dotenv(dotenv_path="config/.env")

logging.basicConfig(level=logging.INFO)

# %% [markdown]
# ## Extracting Data from Open Weather Map

# %%
# Extracting OWM Data

API_KEY = os.getenv("OWM_API_KEY")
BASE_URL = "https://api.openweathermap.org/data/2.5/weather"

# Daftar kota yang akan diambil datanya
CITIES = ["Jakarta", "Tokyo", "London", "New York", "Sydney"]
CITY_LIST_PATH = "../config/city_list.csv"

def fetch_weather_for_city(city: str) -> dict:
    """Ambil data cuaca untuk satu kota"""
    params = {
        "q": city,
        "appid": API_KEY,
        "units": "metric"  # Celsius
    }
    try:
        response = requests.get(BASE_URL, params=params)
        response.raise_for_status()
        data = response.json()
        return {
            "city": data["name"],
            "country": data["sys"]["country"],
            "lat": data["coord"]["lat"],
            "lon": data["coord"]["lon"],
            "temperature": data["main"]["temp"],
            "humidity": data["main"]["humidity"],
            "weather": data["weather"][0]["main"],
            "description": data["weather"][0]["description"],
            "wind_speed": data["wind"]["speed"],
            "timestamp": datetime.utcfromtimestamp(data["dt"]),
            "fetched_at": datetime.utcnow()
        }
    except Exception as e:
        logging.error(f"Error fetching weather for {city}: {e}")
        return None
    
def fetch_weather_by_id(city_id: int) -> dict:
    """Fetch weather data by OpenWeatherMap city ID"""
    params = {
        "id": city_id,
        "appid": API_KEY,
        "units": "metric"
    }
    try:
        response = requests.get(BASE_URL, params=params)
        response.raise_for_status()
        data = response.json()
        return {
            "city_id": data["id"],
            "city": data["name"],
            "country": data["sys"]["country"],
            "lat": data["coord"]["lat"],
            "lon": data["coord"]["lon"],
            "temperature": data["main"]["temp"],
            "humidity": data["main"]["humidity"],
            "weather": data["weather"][0]["main"],
            "description": data["weather"][0]["description"],
            "wind_speed": data["wind"]["speed"],
            "timestamp": datetime.utcfromtimestamp(data["dt"]),
            "fetched_at": datetime.utcnow()
        }
    except Exception as e:
        logging.error(f"Error fetching city ID {city_id}: {e}")
        return None

def fetch_weather_all_cities(city_file: str = CITY_LIST_PATH) -> pd.DataFrame:
    cities_df = pd.read_csv(city_file)
    records = []
    for _, row in cities_df.iterrows():
        result = fetch_weather_by_id(row["id"])
        if result:
            records.append(result)
        else:
            logging.warning(f"Skipping city ID {row['id']} ({row['name']})")
    return pd.DataFrame(records)

# %% [markdown]
# ## Transforming and Enriching the Data

# %%
# Default: Waktu Jakarta (bisa disesuaikan)
WIB = timezone("Asia/Jakarta")

def clean_weather_data(df: pd.DataFrame) -> pd.DataFrame:
    """
    Bersihkan dan transformasi data cuaca:
    - Pastikan tipe data konsisten
    - Drop null penting
    - Konversi timestamp ke timezone lokal
    """
    if df.empty:
        return df

    df = df.dropna(subset=["temperature", "humidity", "weather", "timestamp"])

    df["timestamp"] = pd.to_datetime(df["timestamp"]).dt.tz_localize("UTC").dt.tz_convert(WIB)
    df["fetched_at"] = pd.to_datetime(df["fetched_at"]).dt.tz_localize("UTC").dt.tz_convert(WIB)

    return df


def enrich_weather_data(df: pd.DataFrame) -> pd.DataFrame:
    """
    Tambahkan kolom turunan:
    - temp_category (dingin, hangat, panas)
    - local_time, day_of_week, hour_of_day
    """
    if df.empty:
        return df

    def classify_temp(temp):
        if temp < 20:
            return "Cold"
        elif temp < 30:
            return "Warm"
        else:
            return "Hot"

    df["temp_category"] = df["temperature"].apply(classify_temp)
    df["day_of_week"] = df["timestamp"].dt.day_name()
    df["hour_of_day"] = df["timestamp"].dt.hour

    return df


raw = fetch_weather_all_cities()
clean = clean_weather_data(raw)
enriched = enrich_weather_data(clean)

print(enriched.head())
# Out:
# ERROR:root:Error fetching city ID 1650077: 401 Client Error: Unauthorized for url: https://api.openweathermap.org/data/2.5/weather?id=1650077&units=metric
# WARNING:root:Skipping city ID 1650077 (Banyuwangi)
# ERROR:root:Error fetching city ID 1625822: 401 Client Error: Unauthorized for url: https://api.openweathermap.org/data/2.5/weather?id=1625822&units=metric
# WARNING:root:Skipping city ID 1625822 (Surabaya)
# ERROR:root:Error fetching city ID 1835848: 401 Client Error: Unauthorized for url: https://api.openweathermap.org/data/2.5/weather?id=1835848&units=metric
# WARNING:root:Skipping city ID 1835848 (Seoul)
# ERROR:root:Error fetching city ID 5128581: 401 Client Error: Unauthorized for url: https://api.openweathermap.org/data/2.5/weather?id=5128581&units=metric
# WARNING:root:Skipping city ID 5128581 (New York)
# ERROR:root:Error fetching city ID 292223: 401 Client Error: Unauthorized for url: https://api.openweathermap.org/data/2.5/weather?id=292223&units=metric
# WARNING:root:Skipping city ID 292223 (Dubai)
# ERROR:root:Error fetching city ID 1850147: 401 Client Error: Unauthorized for url: https://api.openweathermap.org/data/2.5/weather?id=1850147&units=metric
# WARNING:root:Skipping city ID 1850147 (Tokyo)
# ERROR:root:Error fetching city ID 360630: 401 Client Error: Unauthorized for url: https://api.openweathermap.org/data/2.5/weather?id=360630&units=metric
# WARNING:root:Skipping city ID 360630 (Cairo)
# ERROR:root:Error fetching city ID 1273294: 401 Client Error: Unauthorized for url: https://api.openweathermap.org/data/2.5/weather?id=1273294&units=metric
# WARNING:root:Skipping city ID 1273294 (Delhi)
# ERROR:root:Error fetching city ID 3435910: 401 Client Error: Unauthorized for url: https://api.openweathermap.org/data/2.5/weather?id=3435910&units=metric
# WARNING:root:Skipping city ID 3435910 (Buenos Aires)
# ERROR:root:Error fetching city ID 1816670: 401 Client Error: Unauthorized for url: https://api.openweathermap.org/data/2.5/weather?id=1816670&units=metric
# WARNING:root:Skipping city ID 1816670 (Beijing)
# ERROR:root:Error fetching city ID 3448439: 401 Client Error: Unauthorized for url: https://api.openweathermap.org/data/2.5/weather?id=3448439&units=metric
# WARNING:root:Skipping city ID 3448439 (Sao Paulo)
# ERROR:root:Error fetching city ID 1796236: 401 Client Error: Unauthorized for url: https://api.openweathermap.org/data/2.5/weather?id=1796236&units=metric
# WARNING:root:Skipping city ID 1796236 (Shanghai)
# ERROR:root:Error fetching city ID 745044: 401 Client Error: Unauthorized for url: https://api.openweathermap.org/data/2.5/weather?id=745044&units=metric
# WARNING:root:Skipping city ID 745044 (Istanbul)
# ERROR:root:Error fetching city ID 2968815: 401 Client Error: Unauthorized for url: https://api.openweathermap.org/data/2.5/weather?id=2968815&units=metric
# WARNING:root:Skipping city ID 2968815 (Paris)
# ERROR:root:Error fetching city ID 3369157: 401 Client Error: Unauthorized for url: https://api.openweathermap.org/data/2.5/weather?id=3369157&units=metric
# WARNING:root:Skipping city ID 3369157 (Cape Town)
# ERROR:root:Error fetching city ID 2147714: 401 Client Error: Unauthorized for url: https://api.openweathermap.org/data/2.5/weather?id=2147714&units=metric
# WARNING:root:Skipping city ID 2147714 (Sydney)
# ERROR:root:Error fetching city ID 993800: 401 Client Error: Unauthorized for url: https://api.openweathermap.org/data/2.5/weather?id=993800&units=metric
# WARNING:root:Skipping city ID 993800 (Johannesburg)
# ERROR:root:Error fetching city ID 1853909: 401 Client Error: Unauthorized for url: https://api.openweathermap.org/data/2.5/weather?id=1853909&units=metric
# WARNING:root:Skipping city ID 1853909 (Osaka)
# ERROR:root:Error fetching city ID 1264527: 401 Client Error: Unauthorized for url: https://api.openweathermap.org/data/2.5/weather?id=1264527&units=metric
# WARNING:root:Skipping city ID 1264527 (Mumbai)
# ERROR:root:Error fetching city ID 344979: 401 Client Error: Unauthorized for url: https://api.openweathermap.org/data/2.5/weather?id=344979&units=metric
# WARNING:root:Skipping city ID 344979 (Addis Ababa)
# ERROR:root:Error fetching city ID 745042: 401 Client Error: Unauthorized for url: https://api.openweathermap.org/data/2.5/weather?id=745042&units=metric
# WARNING:root:Skipping city ID 745042 (Ankara)
# ERROR:root:Error fetching city ID 6167865: 401 Client Error: Unauthorized for url: https://api.openweathermap.org/data/2.5/weather?id=6167865&units=metric
# WARNING:root:Skipping city ID 6167865 (Toronto)
# ERROR:root:Error fetching city ID 2643743: 401 Client Error: Unauthorized for url: https://api.openweathermap.org/data/2.5/weather?id=2643743&units=metric
# WARNING:root:Skipping city ID 2643743 (London)
# ERROR:root:Error fetching city ID 1701668: 401 Client Error: Unauthorized for url: https://api.openweathermap.org/data/2.5/weather?id=1701668&units=metric
# WARNING:root:Skipping city ID 1701668 (Manila)
# ERROR:root:Error fetching city ID 3871336: 401 Client Error: Unauthorized for url: https://api.openweathermap.org/data/2.5/weather?id=3871336&units=metric
# WARNING:root:Skipping city ID 3871336 (Santiago)
# ERROR:root:Error fetching city ID 524901: 401 Client Error: Unauthorized for url: https://api.openweathermap.org/data/2.5/weather?id=524901&units=metric
# WARNING:root:Skipping city ID 524901 (Moscow)
# ERROR:root:Error fetching city ID 1277333: 401 Client Error: Unauthorized for url: https://api.openweathermap.org/data/2.5/weather?id=1277333&units=metric
# WARNING:root:Skipping city ID 1277333 (Bangalore)
# ERROR:root:Error fetching city ID 3067696: 401 Client Error: Unauthorized for url: https://api.openweathermap.org/data/2.5/weather?id=3067696&units=metric
# WARNING:root:Skipping city ID 3067696 (Prague)
# ERROR:root:Error fetching city ID 1856057: 401 Client Error: Unauthorized for url: https://api.openweathermap.org/data/2.5/weather?id=1856057&units=metric
# WARNING:root:Skipping city ID 1856057 (Nagoya)
# ERROR:root:Error fetching city ID 1261481: 401 Client Error: Unauthorized for url: https://api.openweathermap.org/data/2.5/weather?id=1261481&units=metric
# WARNING:root:Skipping city ID 1261481 (New Delhi)
# ERROR:root:Error fetching city ID 1733046: 401 Client Error: Unauthorized for url: https://api.openweathermap.org/data/2.5/weather?id=1733046&units=metric
# WARNING:root:Skipping city ID 1733046 (Kuala Lumpur)
# ERROR:root:Error fetching city ID 1880252: 401 Client Error: Unauthorized for url: https://api.openweathermap.org/data/2.5/weather?id=1880252&units=metric
# WARNING:root:Skipping city ID 1880252 (Singapore)
# ERROR:root:Error fetching city ID 6160752: 401 Client Error: Unauthorized for url: https://api.openweathermap.org/data/2.5/weather?id=6160752&units=metric
# WARNING:root:Skipping city ID 6160752 (Ottawa)
# ERROR:root:Error fetching city ID 2174003: 401 Client Error: Unauthorized for url: https://api.openweathermap.org/data/2.5/weather?id=2174003&units=metric
# WARNING:root:Skipping city ID 2174003 (Brisbane)
# Empty DataFrame
# Columns: []
# Index: []

# %%
# Extract
raw_data = fetch_weather_all_cities()
if raw_data.empty:
    logging.error("No data fetched from API. Pipeline stopped.")


# Transform
cleaned = clean_weather_data(raw_data)
enriched = enrich_weather_data(cleaned)

if enriched.empty:
    logging.error("Transformed data is empty. Pipeline stopped.")
# Out:
# ERROR:root:Error fetching city ID 1650077: 401 Client Error: Unauthorized for url: https://api.openweathermap.org/data/2.5/weather?id=1650077&units=metric
# WARNING:root:Skipping city ID 1650077 (Banyuwangi)
# ERROR:root:Error fetching city ID 1625822: 401 Client Error: Unauthorized for url: https://api.openweathermap.org/data/2.5/weather?id=1625822&units=metric
# WARNING:root:Skipping city ID 1625822 (Surabaya)
# ERROR:root:Error fetching city ID 1835848: 401 Client Error: Unauthorized for url: https://api.openweathermap.org/data/2.5/weather?id=1835848&units=metric
# WARNING:root:Skipping city ID 1835848 (Seoul)
# ERROR:root:Error fetching city ID 5128581: 401 Client Error: Unauthorized for url: https://api.openweathermap.org/data/2.5/weather?id=5128581&units=metric
# WARNING:root:Skipping city ID 5128581 (New York)
# ERROR:root:Error fetching city ID 292223: 401 Client Error: Unauthorized for url: https://api.openweathermap.org/data/2.5/weather?id=292223&units=metric
# WARNING:root:Skipping city ID 292223 (Dubai)
# ERROR:root:Error fetching city ID 1850147: 401 Client Error: Unauthorized for url: https://api.openweathermap.org/data/2.5/weather?id=1850147&units=metric
# WARNING:root:Skipping city ID 1850147 (Tokyo)
# ERROR:root:Error fetching city ID 360630: 401 Client Error: Unauthorized for url: https://api.openweathermap.org/data/2.5/weather?id=360630&units=metric
# WARNING:root:Skipping city ID 360630 (Cairo)
# ERROR:root:Error fetching city ID 1273294: 401 Client Error: Unauthorized for url: https://api.openweathermap.org/data/2.5/weather?id=1273294&units=metric
# WARNING:root:Skipping city ID 1273294 (Delhi)
# ERROR:root:Error fetching city ID 3435910: 401 Client Error: Unauthorized for url: https://api.openweathermap.org/data/2.5/weather?id=3435910&units=metric
# WARNING:root:Skipping city ID 3435910 (Buenos Aires)
# ERROR:root:Error fetching city ID 1816670: 401 Client Error: Unauthorized for url: https://api.openweathermap.org/data/2.5/weather?id=1816670&units=metric
# WARNING:root:Skipping city ID 1816670 (Beijing)
# ERROR:root:Error fetching city ID 3448439: 401 Client Error: Unauthorized for url: https://api.openweathermap.org/data/2.5/weather?id=3448439&units=metric
# WARNING:root:Skipping city ID 3448439 (Sao Paulo)
# ERROR:root:Error fetching city ID 1796236: 401 Client Error: Unauthorized for url: https://api.openweathermap.org/data/2.5/weather?id=1796236&units=metric
# WARNING:root:Skipping city ID 1796236 (Shanghai)
# ERROR:root:Error fetching city ID 745044: 401 Client Error: Unauthorized for url: https://api.openweathermap.org/data/2.5/weather?id=745044&units=metric
# WARNING:root:Skipping city ID 745044 (Istanbul)
# ERROR:root:Error fetching city ID 2968815: 401 Client Error: Unauthorized for url: https://api.openweathermap.org/data/2.5/weather?id=2968815&units=metric
# WARNING:root:Skipping city ID 2968815 (Paris)
# ERROR:root:Error fetching city ID 3369157: 401 Client Error: Unauthorized for url: https://api.openweathermap.org/data/2.5/weather?id=3369157&units=metric
# WARNING:root:Skipping city ID 3369157 (Cape Town)
# ERROR:root:Error fetching city ID 2147714: 401 Client Error: Unauthorized for url: https://api.openweathermap.org/data/2.5/weather?id=2147714&units=metric
# WARNING:root:Skipping city ID 2147714 (Sydney)
# ERROR:root:Error fetching city ID 993800: 401 Client Error: Unauthorized for url: https://api.openweathermap.org/data/2.5/weather?id=993800&units=metric
# WARNING:root:Skipping city ID 993800 (Johannesburg)
# ERROR:root:Error fetching city ID 1853909: 401 Client Error: Unauthorized for url: https://api.openweathermap.org/data/2.5/weather?id=1853909&units=metric
# WARNING:root:Skipping city ID 1853909 (Osaka)
# ERROR:root:Error fetching city ID 1264527: 401 Client Error: Unauthorized for url: https://api.openweathermap.org/data/2.5/weather?id=1264527&units=metric
# WARNING:root:Skipping city ID 1264527 (Mumbai)
# ERROR:root:Error fetching city ID 344979: 401 Client Error: Unauthorized for url: https://api.openweathermap.org/data/2.5/weather?id=344979&units=metric
# WARNING:root:Skipping city ID 344979 (Addis Ababa)
# ERROR:root:Error fetching city ID 745042: 401 Client Error: Unauthorized for url: https://api.openweathermap.org/data/2.5/weather?id=745042&units=metric
# WARNING:root:Skipping city ID 745042 (Ankara)
# ERROR:root:Error fetching city ID 6167865: 401 Client Error: Unauthorized for url: https://api.openweathermap.org/data/2.5/weather?id=6167865&units=metric
# WARNING:root:Skipping city ID 6167865 (Toronto)
# ERROR:root:Error fetching city ID 2643743: 401 Client Error: Unauthorized for url: https://api.openweathermap.org/data/2.5/weather?id=2643743&units=metric
# WARNING:root:Skipping city ID 2643743 (London)
# ERROR:root:Error fetching city ID 1701668: 401 Client Error: Unauthorized for url: https://api.openweathermap.org/data/2.5/weather?id=1701668&units=metric
# WARNING:root:Skipping city ID 1701668 (Manila)
# ERROR:root:Error fetching city ID 3871336: 401 Client Error: Unauthorized for url: https://api.openweathermap.org/data/2.5/weather?id=3871336&units=metric
# WARNING:root:Skipping city ID 3871336 (Santiago)
# ERROR:root:Error fetching city ID 524901: 401 Client Error: Unauthorized for url: https://api.openweathermap.org/data/2.5/weather?id=524901&units=metric
# WARNING:root:Skipping city ID 524901 (Moscow)
# ERROR:root:Error fetching city ID 1277333: 401 Client Error: Unauthorized for url: https://api.openweathermap.org/data/2.5/weather?id=1277333&units=metric
# WARNING:root:Skipping city ID 1277333 (Bangalore)
# ERROR:root:Error fetching city ID 3067696: 401 Client Error: Unauthorized for url: https://api.openweathermap.org/data/2.5/weather?id=3067696&units=metric
# WARNING:root:Skipping city ID 3067696 (Prague)
# ERROR:root:Error fetching city ID 1856057: 401 Client Error: Unauthorized for url: https://api.openweathermap.org/data/2.5/weather?id=1856057&units=metric
# WARNING:root:Skipping city ID 1856057 (Nagoya)
# ERROR:root:Error fetching city ID 1261481: 401 Client Error: Unauthorized for url: https://api.openweathermap.org/data/2.5/weather?id=1261481&units=metric
# WARNING:root:Skipping city ID 1261481 (New Delhi)
# ERROR:root:Error fetching city ID 1733046: 401 Client Error: Unauthorized for url: https://api.openweathermap.org/data/2.5/weather?id=1733046&units=metric
# WARNING:root:Skipping city ID 1733046 (Kuala Lumpur)
# ERROR:root:Error fetching city ID 1880252: 401 Client Error: Unauthorized for url: https://api.openweathermap.org/data/2.5/weather?id=1880252&units=metric
# WARNING:root:Skipping city ID 1880252 (Singapore)
# ERROR:root:Error fetching city ID 6160752: 401 Client Error: Unauthorized for url: https://api.openweathermap.org/data/2.5/weather?id=6160752&units=metric
# WARNING:root:Skipping city ID 6160752 (Ottawa)
# ERROR:root:Error fetching city ID 2174003: 401 Client Error: Unauthorized for url: https://api.openweathermap.org/data/2.5/weather?id=2174003&units=metric
# WARNING:root:Skipping city ID 2174003 (Brisbane)
# Empty DataFrame
# Columns: []
# Index: []

# %%
API_KEY = os.getenv("abcdefg")
BASE_URL = "https://api.openweathermap.org/data/2.5/weather"
CITY_LIST_PATH = "config/city_list.csv"

params = {
    "id": 1234567,
    "appid": API_KEY,
    "units": "metric"
}

print(BASE_URL, params)
# Out:
# https://api.openweathermap.org/data/2.5/weather {'id': 1234567, 'appid': None, 'units': 'metric'}
